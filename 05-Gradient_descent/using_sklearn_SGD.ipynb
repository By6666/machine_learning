# %% [markdown]
# # 使用sklearn 中的SGD

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets

# %%
boston = datasets.load_boston()
x = boston.data
y = boston.target

x = x[y < 50]
y = y[y < 50]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 666)

# %% [markdown]
# ## 归一化处理

# %%
from sklearn.preprocessing import StandardScaler

# %%
data_stand = StandardScaler()
data_stand.fit(x_train)

x_train_std = data_stand.transform(x_train)
x_test_std = data_stand.transform(x_test)

# %% [markdown]
# ## 使用sklearn 中的SGD

# %%
from sklearn.linear_model import SGDRegressor

# %%
sgd_reg = SGDRegressor(n_iter_no_change = 100,verbose=1)
# %time sgd_reg.fit(x_train_std, y_train)
sgd_reg.score(x_test_std, y_test)
# Out:
# -- Epoch 1
# Norm: 3.50, NNZs: 13, Bias: 14.869763, T: 392, Avg. loss: 89.357223
# Total training time: 0.00 seconds.
# -- Epoch 2
# Norm: 3.97, NNZs: 13, Bias: 18.568031, T: 784, Avg. loss: 19.462759
# Total training time: 0.00 seconds.
# -- Epoch 3
# Norm: 4.40, NNZs: 13, Bias: 20.047287, T: 1176, Avg. loss: 10.342711
# Total training time: 0.00 seconds.
# -- Epoch 4
# Norm: 4.49, NNZs: 13, Bias: 20.755914, T: 1568, Avg. loss: 8.479646
# Total training time: 0.00 seconds.
# -- Epoch 5
# Norm: 4.68, NNZs: 13, Bias: 21.108974, T: 1960, Avg. loss: 7.911724
# Total training time: 0.00 seconds.
# -- Epoch 6
# Norm: 4.73, NNZs: 13, Bias: 21.268496, T: 2352, Avg. loss: 7.738844
# Total training time: 0.00 seconds.
# -- Epoch 7
# Norm: 4.88, NNZs: 13, Bias: 21.380644, T: 2744, Avg. loss: 7.633277
# Total training time: 0.00 seconds.
# -- Epoch 8
# Norm: 4.81, NNZs: 13, Bias: 21.417209, T: 3136, Avg. loss: 7.566745
# Total training time: 0.00 seconds.
# -- Epoch 9
# ...
